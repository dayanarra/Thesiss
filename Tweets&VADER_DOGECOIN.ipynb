# %% [markdown]
# # Final version of tweet data preprocessing.
#
# First, merging all datasets for DOGECOIN
#  as each day of data was saved as a separate file.

# %%
import pandas as pd

# %%
# reading all datasets for Bitcoin tweets

doge0105 = pd.read_pickle("doge05_01.pkl")
doge3004 = pd.read_pickle('doge04_30.pkl')
doge2904 = pd.read_pickle('doge04_29.pkl')
doge2804 = pd.read_pickle('doge04_28.pkl')
doge2704 = pd.read_pickle('doge04_27.pkl')
doge2604 = pd.read_pickle('doge04_26.pkl')
doge2504 = pd.read_pickle('doge04_25.pkl')
doge2404 = pd.read_pickle('doge04_24.pkl')
doge2304 = pd.read_pickle('doge04_23.pkl')
doge2204 = pd.read_pickle('doge04_22.pkl')
doge2104 = pd.read_pickle('doge04_21.pkl')
doge2004 = pd.read_pickle('doge04_20.pkl')
doge1904 = pd.read_pickle('doge04_19.pkl')
doge1804 = pd.read_pickle('doge04_18.pkl')
doge1704 = pd.read_pickle('doge04_17.pkl')
doge1604 = pd.read_pickle('doge04_16.pkl')
doge1504 = pd.read_pickle('doge04_15.pkl')
doge1404 = pd.read_pickle('doge04_14.pkl')
doge1304 = pd.read_pickle('doge04_13.pkl')
doge1204 = pd.read_pickle('doge04_12.pkl')
doge1104 = pd.read_pickle('doge04_11.pkl')
doge1004 = pd.read_pickle('doge04_10.pkl')
doge0904 = pd.read_pickle('doge04_09.pkl')
doge0804 = pd.read_pickle('doge04_08.pkl')
doge0704 = pd.read_pickle('doge04_07.pkl')
doge0604 = pd.read_pickle('doge04_06.pkl')
doge0504 = pd.read_pickle('doge04_05.pkl')
doge0404 = pd.read_pickle('doge04_04.pkl')
doge0304 = pd.read_pickle('doge04_03.pkl')
doge0204 = pd.read_pickle('doge04_02.pkl')
doge0104 = pd.read_pickle('doge04_01.pkl')
doge3103 = pd.read_pickle('doge31_03.pkl')
doge3003 = pd.read_pickle('doge30_03.pkl')
doge2903 = pd.read_pickle('doge29_03.pkl')
doge2803 = pd.read_pickle('doge28_03.pkl')
doge2703 = pd.read_pickle('doge27_03.pkl')
doge2603 = pd.read_pickle('doge26_03.pkl')
doge2503 = pd.read_pickle('doge25_003.pkl')

# %%
dogi = [doge0105,doge3004,doge2904,doge2804,doge2704,doge2604,doge2504,doge2404,doge2304,doge2204,doge2104,doge2004,doge1904,doge1804,doge1704,doge1604,doge1504,doge1404,doge1304,doge1204,doge1104,doge1004,doge0904,doge0804,doge0704,doge0604,doge0504,doge0404,doge0304,doge0204,doge0104,doge3103,doge3003,doge2903,doge2803,doge2903,doge2803]

# %%
dogtweets = pd.concat(dogi, ignore_index= True)

# %%
dogtweets
# Out:
#                             date                            user_link  \
# 0      2022-05-01 23:59:58+00:00  https://twitter.com/tearsintherain1
# 1      2022-05-01 23:59:53+00:00     https://twitter.com/CryptoPropel
# 2      2022-05-01 23:59:19+00:00       https://twitter.com/DogeHourly
# 3      2022-05-01 23:58:06+00:00         https://twitter.com/zalerion
# 4      2022-05-01 23:57:13+00:00        https://twitter.com/TickerTop
# ...                          ...                                  ...
# 141089 2022-03-28 00:00:03+00:00   https://twitter.com/DogePriceAlert
# 141090 2022-03-28 00:00:03+00:00   https://twitter.com/DogeCoinBotEUR
# 141091 2022-03-28 00:00:02+00:00    https://twitter.com/Dogecoinvalue
# 141092 2022-03-28 00:00:02+00:00   https://twitter.com/dogecointicker
# 141093 2022-03-28 00:00:00+00:00   https://twitter.com/babydoge_value
#
#                username              user_id  \
# 0       tearsintherain1            496949253
# ...

# %%
# Saving the dataframe of all uncleaned tweets for bitcoin
dogtweets.to_pickle('all_dog_tweets_unclean.pkl')

# %% [markdown]
# # Data cleaning
#
# 1. Checking for duplicates & missing values
# 2. Cleaning the tweets

# %%
# no missing data
dogtweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141094 entries, 0 to 141093
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             141094 non-null  datetime64[ns, UTC]
#  1   user_link        141094 non-null  object
#  2   username         141094 non-null  object
#  3   user_id          141094 non-null  int64
#  4   content          141094 non-null  object
#  5   retweet_count    141094 non-null  int64
#  6   like_count       141094 non-null  int64
#  7   followers_count  141094 non-null  int64
#  8   verified         141094 non-null  bool
# dtypes: bool(1), datetime64[ns, UTC](1), int64(4), object(3)
# memory usage: 8.7+ MB

# %%
# Some statistics of numeric values
dogtweets.describe()
# Out:
#             user_id  retweet_count     like_count  followers_count
# count  1.410940e+05  141094.000000  141094.000000     1.410940e+05
# mean   9.987140e+17       3.205934      13.670992     1.803212e+04
# std    5.738723e+17      47.010959     171.177478     2.207530e+05
# min    5.280000e+02       0.000000       0.000000     0.000000e+00
# 25%    8.055323e+17       0.000000       0.000000     1.460000e+02
# 50%    1.295245e+18       0.000000       1.000000     8.930000e+02
# 75%    1.422257e+18       1.000000       2.000000     6.543000e+03
# max    1.520867e+18    7846.000000   40284.000000     2.661876e+07

# %%
dogtweets
# Out:
#                             date                            user_link  \
# 0      2022-05-01 23:59:58+00:00  https://twitter.com/tearsintherain1
# 1      2022-05-01 23:59:53+00:00     https://twitter.com/CryptoPropel
# 2      2022-05-01 23:59:19+00:00       https://twitter.com/DogeHourly
# 3      2022-05-01 23:58:06+00:00         https://twitter.com/zalerion
# 4      2022-05-01 23:57:13+00:00        https://twitter.com/TickerTop
# ...                          ...                                  ...
# 141089 2022-03-28 00:00:03+00:00   https://twitter.com/DogePriceAlert
# 141090 2022-03-28 00:00:03+00:00   https://twitter.com/DogeCoinBotEUR
# 141091 2022-03-28 00:00:02+00:00    https://twitter.com/Dogecoinvalue
# 141092 2022-03-28 00:00:02+00:00   https://twitter.com/dogecointicker
# 141093 2022-03-28 00:00:00+00:00   https://twitter.com/babydoge_value
#
#                username              user_id  \
# 0       tearsintherain1            496949253
# ...

# %%
len(dogtweets)
# Out:
# 141094

# %%
#Checking for duplicated tweets in the content column
boolean = dogtweets.duplicated(subset=['content']).any()
boolean
# Out:
# True

# %%
#Formating date column
dogtweets['YY-MM-DD'] = dogtweets['date'].dt.strftime('%Y/%m/%d')
dogtweets['YY-MM-DD'] = pd.to_datetime(dogtweets['YY-MM-DD'])

# %%
dogtweets
# Out:
#                             date                            user_link  \
# 0      2022-05-01 23:59:58+00:00  https://twitter.com/tearsintherain1
# 1      2022-05-01 23:59:53+00:00     https://twitter.com/CryptoPropel
# 2      2022-05-01 23:59:19+00:00       https://twitter.com/DogeHourly
# 3      2022-05-01 23:58:06+00:00         https://twitter.com/zalerion
# 4      2022-05-01 23:57:13+00:00        https://twitter.com/TickerTop
# ...                          ...                                  ...
# 141089 2022-03-28 00:00:03+00:00   https://twitter.com/DogePriceAlert
# 141090 2022-03-28 00:00:03+00:00   https://twitter.com/DogeCoinBotEUR
# 141091 2022-03-28 00:00:02+00:00    https://twitter.com/Dogecoinvalue
# 141092 2022-03-28 00:00:02+00:00   https://twitter.com/dogecointicker
# 141093 2022-03-28 00:00:00+00:00   https://twitter.com/babydoge_value
#
#                username              user_id  \
# 0       tearsintherain1            496949253
# ...

# %%
# Dropping useless columns

dogtweets = dogtweets.drop(['user_link', 'username', 'date'], axis = 1)

# %%
dogtweets['YY-MM-DD'].unique()
# Out:
# array(['2022-05-01T00:00:00.000000000', '2022-04-30T00:00:00.000000000',
#        '2022-04-29T00:00:00.000000000', '2022-04-28T00:00:00.000000000',
#        '2022-04-27T00:00:00.000000000', '2022-04-26T00:00:00.000000000',
#        '2022-04-25T00:00:00.000000000', '2022-04-24T00:00:00.000000000',
#        '2022-04-23T00:00:00.000000000', '2022-04-22T00:00:00.000000000',
#        '2022-04-21T00:00:00.000000000', '2022-04-20T00:00:00.000000000',
#        '2022-04-19T00:00:00.000000000', '2022-04-18T00:00:00.000000000',
#        '2022-04-17T00:00:00.000000000', '2022-04-16T00:00:00.000000000',
#        '2022-04-15T00:00:00.000000000', '2022-04-14T00:00:00.000000000',
#        '2022-04-13T00:00:00.000000000', '2022-04-12T00:00:00.000000000',
#        '2022-04-11T00:00:00.000000000', '2022-04-10T00:00:00.000000000',
#        '2022-04-09T00:00:00.000000000', '2022-04-08T00:00:00.000000000',
#        '2022-04-07T00:00:00.000000000', '2022-04-06T00:00:00.000000000',
# ...

# %%
# Number of tweets per day
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = 28,10

plt.hist(dogtweets['YY-MM-DD'], bins=35,color = 'royalblue', rwidth=0.7)
plt.ylabel('Number of tweets')
plt.xlabel('Date')
plt.title("Number of tweets for Dogecoin per day ", fontdict=None, position= [0.50,1.05], size = 'x-large')
plt.savefig('demo.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

plt.show()
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/1314726004.py:10: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('demo.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/1314726004.py:10: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('demo.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

# %%
# Select duplicate rows except first occurrence for the content column
duplicateRowsDF = dogtweets[dogtweets.duplicated(['content'])]
duplicateRowsDF
len(duplicateRowsDF)

# 18859 duplicates

# There are  duplicated tweets, the duplicated function looks for an exact match in the text, so those tweets are most likely copy/paste content coming from bots, because the data set does not contain retweets. Thus, removing them, expect for the first occurrence, would not compromise the data.
# Out:
# 18859

# %%
#Dropping the duplicated tweets, and keeping the first occurrence of the content
dogtweets = dogtweets.drop_duplicates(subset='content', keep="first")

# %%
# Check if retweet = 0 and follower = 0 is coming from bot accounts, not really

dogbol = dogtweets[(dogtweets['retweet_count'] == 0) & (dogtweets['followers_count']  == 0)]

# %%
dogbol
# Out:
#                     user_id  \
# 137     1518850325880487936
# 379     1517347661921370112
# 570     1443458248267288578
# 593     1381437488057683968
# 824     1510217317124395019
# ...                     ...
# 134823  1467675015802146819
# 134825  1467673936620318722
# 134856  1467673936620318722
# 134908  1467675015802146819
# 134911  1467673936620318722
#
#                                                   content  retweet_count  \
# 137              #dogecoin should become quite important.              0
# 379     kucoincom Winner !!!♪ Baby Dogecoin ♪ #BabyDog...              0
# 570               Tell me @elonmusk should I buy dogecoin              0
# 593     Dogecoin for the win \n#dogecoin #facts https:...              0
# 824     Elon Musk suddenly raises the price of Dogecoi...              0
# ...                                                   ...            ...
# 134823  "Bitcoin, Ethereum, Dogecoin Hold Steady Amid ...              0
# ...

# %% [markdown]
# # Cleaning tweets
#
# The cleaning of the data will involve removing some punctuation, hyperlinks and hashtags.

# %%
# removing only some punctuation, because the VADER package takes into account ! and ? which influence the polarity of the text

import re
punct = '"#$%&\'()*+,-./:;<=>@[\\]^_`{|}~'
punct
# Out:
# '"#$%&\'()*+,-./:;<=>@[\\]^_`{|}~'

# %% [markdown]
# Below is the function to clean tweets. Initial cleaning will involve removing some punctuation, removing https links, removing /r & /n, and removing hashtags in front of words.
#
# - The arguments in comments can further clean the text by removing numbers, emojis and putting everything in lowercase. But the VADER algorithm recognizes emojis, and caps lock, and ! ? as expressing emotions. Thus, initially they will be kept, in the modeling stage further cleaning can be applied if the performance is unsatisfactory.

# %%
# Function to clean tweets
def cleantwt(text):
    text  = "".join([char for char in text if char not in punct]) #removes punctuation
    text = re.sub('[0-9]+', '', text) #removes numbers
    text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text) #Remove http links
    text = text.replace('\r', '').replace('\n', ' ').replace('\n', ' ') #.lower() #remove \n and \r and lowercase
    text = text.replace("#", "").replace("_", " ")
    #text = re.sub(r'[^\x00-\x7f]',r'', text) #remove non utf8/ascii characters such as '\x9a\x91\x97\x9a\x97' this removes emojis
    return text

dogtweets['clean_tweet'] = dogtweets['content'].apply(lambda x: cleantwt(x))

# %%
dogtweets
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135052   902282851499917312
# 135054  1392056896845144067
# 135055           2232368590
# 135056           2435986338
# 135057  1408912771563933700
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135052  $DOGE: Dogecoin's price has changed by 5.46% i...              9
# ...

# %%
# Checking for new duplicates in the clean_Tweet
duplicateRowsDFnew = dogtweets[dogtweets.duplicated(['clean_tweet'])]
duplicateRowsDFnew
print(len(duplicateRowsDFnew))
dogtweets = dogtweets.drop_duplicates(subset='clean_tweet', keep="first")
# Out:
# 19217

# %%
dogtweets
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135045  1387922429583007755
# 135048  1361760524162113538
# 135049  1178811384387293187
# 135050  1222346095398998022
# 135051  1345670404350771201
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135045  Dogecoin Leaps! But Here's Why An Even Bigger ...              0
# ...

# %% [markdown]
# # VADER
#
# Applying the sentiment analyzer on the tweets, by first computing the 4 VADER scores(compound, positive, negative, and neutral).

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
analyzer = SentimentIntensityAnalyzer()
dogtweets['compound'] = [analyzer.polarity_scores(x)['compound'] for x in dogtweets['clean_tweet']]
dogtweets['neg'] = [analyzer.polarity_scores(x)['neg'] for x in dogtweets['clean_tweet']]
dogtweets['neu'] = [analyzer.polarity_scores(x)['neu'] for x in dogtweets['clean_tweet']]
dogtweets['pos'] = [analyzer.polarity_scores(x)['pos'] for x in dogtweets['clean_tweet']]
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/3694986972.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dogtweets['compound'] = [analyzer.polarity_scores(x)['compound'] for x in dogtweets['clean_tweet']]
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/3694986972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dogtweets['neg'] = [analyzer.polarity_scores(x)['neg'] for x in dogtweets['clean_tweet']]
# ...

# %%
dogtweets

#Some crypto slang is wrongfully interpreted by VADER, so update the lexicon
# fire emoji, rocket emoji, to the moon, moooning, fire
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135045  1387922429583007755
# 135048  1361760524162113538
# 135049  1178811384387293187
# 135050  1222346095398998022
# 135051  1345670404350771201
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135045  Dogecoin Leaps! But Here's Why An Even Bigger ...              0
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

new_words = {
    'moon': 1.5,
    'pump': 1.5,
    'fire': 1.5,
    '🔥': 1.5,
    '🚀': 1.5

}

analyzer = SentimentIntensityAnalyzer()

analyzer.lexicon.update(new_words)

# %%
# Recompute the scores
dogtweets['compound'] = [analyzer.polarity_scores(x)['compound'] for x in dogtweets['clean_tweet']]
dogtweets['neg'] = [analyzer.polarity_scores(x)['neg'] for x in dogtweets['clean_tweet']]
dogtweets['neu'] = [analyzer.polarity_scores(x)['neu'] for x in dogtweets['clean_tweet']]
dogtweets['pos'] = [analyzer.polarity_scores(x)['pos'] for x in dogtweets['clean_tweet']]
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/3967431864.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dogtweets['pos'] = [analyzer.polarity_scores(x)['pos'] for x in dogtweets['clean_tweet']]
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/3967431864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dogtweets['compound'] = [analyzer.polarity_scores(x)['compound'] for x in dogtweets['clean_tweet']]
# ...

# %%
dogtweets
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135045  1387922429583007755
# 135048  1361760524162113538
# 135049  1178811384387293187
# 135050  1222346095398998022
# 135051  1345670404350771201
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135045  Dogecoin Leaps! But Here's Why An Even Bigger ...              0
# ...

# %% [markdown]
# Adding a column 'sentiment' where each tweet is classified as either positive, negative or neutral.

# %%
result = []
for value in dogtweets["compound"]:
    if value >= 0.05:
        result.append("Positive")
    elif value <= (-0.05):
        result.append("Negative")
    else:
        result.append("Neutral")

dogtweets["Sentiment"] = result
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/2495534338.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dogtweets["Sentiment"] = result

# %%
dogtweets

#Observation - tweets with many emojis receive a very high positive compound score, possibly later try with removing emojis
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135045  1387922429583007755
# 135048  1361760524162113538
# 135049  1178811384387293187
# 135050  1222346095398998022
# 135051  1345670404350771201
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135045  Dogecoin Leaps! But Here's Why An Even Bigger ...              0
# ...

# %%
# Saving
dogtweets.to_pickle('LAST_dogtweet_cleaning_and_vader_scores.pkl')

# %%
# Example of a very positive tweet - cleaned, original and compound score
print(dogtweets.loc[41734, 'clean_tweet'])
print(dogtweets.loc[41734, 'compound'])
# Out:
# Ronaldo shows what he loves   ♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️ ♥️♥️♥️ DOGECOIN ♥️♥️♥️ ♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️  dogecoin httpstcoMxUwOuoH
# 0.9991

# %%
# Example of very negative tweet - cleaned, uncleaned, compound score
print(dogtweets.loc[57150,'clean_tweet'])
print(dogtweets.loc[57150, 'compound'])
# Out:
# Shiba Dogecoin Among Biggest Losers as Macro Fears Lead to Market Fall lol Big MF banks need to be dropped in the ocean all of them one by one with nothing but a meat necklace n let them die Fuck them all these guys r the reason American families r broke n poor n homeless
# -0.9688

# %%
dogtweets
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135045  1387922429583007755
# 135048  1361760524162113538
# 135049  1178811384387293187
# 135050  1222346095398998022
# 135051  1345670404350771201
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135045  Dogecoin Leaps! But Here's Why An Even Bigger ...              0
# ...

# %%
dogtweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103018 entries, 0 to 135051
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          103018 non-null  int64
#  1   content          103018 non-null  object
#  2   retweet_count    103018 non-null  int64
#  3   like_count       103018 non-null  int64
#  4   followers_count  103018 non-null  int64
#  5   verified         103018 non-null  bool
#  6   YY-MM-DD         103018 non-null  datetime64[ns]
#  7   clean_tweet      103018 non-null  object
#  8   compound         103018 non-null  float64
#  9   neg              103018 non-null  float64
#  10  neu              103018 non-null  float64
#  11  pos              103018 non-null  float64
#  12  Sentiment        103018 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(4), object(3)
# memory usage: 14.3+ MB

# %% [markdown]
# # EDA
#
# Some exploratory data analysis will be performed.
#
# First, check the overall distribution of the sentiment category.

# %%
import matplotlib.pyplot as plt
se = dogtweets['Sentiment'].value_counts(sort=False).plot(kind = 'bar')
se.set_xlabel('Sentiment', fontsize=18)
se.set_ylabel('Amount of tweets', fontsize=18)
se.set_title('Sentiment Distribution Dogecoin', fontsize=18)
plt.savefig('dogesent.png',dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
plt.show()
#interesting, the dataset is dominated by positive and neutral tweets, if used in this format keep in mind that the negative class is underrepresented. Maybe removing the emojis would result in a more balanced dataset. Abraham(2018) also concludes that sentiment stays positive regardless of price swings, double check there.
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/1623019346.py:6: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogesent.png',dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/1623019346.py:6: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogesent.png',dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

# %%
dogtweets['Sentiment'].value_counts()
# Out:
# Positive    47681
# Neutral     42533
# Negative    12804
# Name: Sentiment, dtype: int64

# %%
len(dogtweets)
# Out:
# 103018

# %%
# The mean compound score per day, most likely this metric will be used in the predictive models

avsentiment = dogtweets.groupby('YY-MM-DD')['compound'].mean()

#dogtweets['m_compound'] = dogtweets.groupby('YY-MM-DD')['compound'].mean()

avsentiment

avsentiment.to_pickle('av_compound_1stclean_DOGE_LAST.pkl')

# %%
avsentiment
# Out:
# YY-MM-DD
# 2022-03-28    0.200202
# 2022-03-29    0.231560
# 2022-03-30    0.216748
# 2022-03-31    0.185723
# 2022-04-01    0.168305
# 2022-04-02    0.219305
# 2022-04-03    0.151238
# 2022-04-04    0.216350
# 2022-04-05    0.197334
# 2022-04-06    0.183847
# 2022-04-07    0.156316
# 2022-04-08    0.224081
# 2022-04-09    0.216776
# 2022-04-10    0.191385
# 2022-04-11    0.176301
# 2022-04-12    0.185495
# 2022-04-13    0.191469
# 2022-04-14    0.176486
# 2022-04-15    0.180433
# 2022-04-16    0.175731
# 2022-04-17    0.207495
# 2022-04-18    0.149348
# 2022-04-19    0.182835
# 2022-04-20    0.217874
# 2022-04-21    0.195323
# 2022-04-22    0.174751
# 2022-04-23    0.179565
# 2022-04-24    0.209375
# 2022-04-25    0.215886
# 2022-04-26    0.179031
# 2022-04-27    0.152755
# 2022-04-28    0.198271
# 2022-04-29    0.227909
# 2022-04-30    0.212694
# 2022-05-01    0.195508
# Name: compound, dtype: float64

# %%
#Plotting the average compound score, use this plot to compare it with the price movements of bitcoin
p = plt.plot(avsentiment.index, avsentiment.values)

plt.ylabel('Compound score')
plt.xlabel('Date')
plt.title("Average Daily Compound Score for Dogecoin", fontdict=None, position= [0.50,1.05], size = 'x-large')
plt.savefig('dogecompound.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

plt.show()
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/1493242657.py:7: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogecompound.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/1493242657.py:7: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogecompound.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

# %%
# The mean positive score per day
avsentimentpos = dogtweets.groupby('YY-MM-DD')['pos'].mean()

avsentimentpos

avsentimentpos.to_pickle('av_positive_1stcleanbit_DOGE_LAST.pkl')

# %%
# The mean negative score per day
avsentimentneg = dogtweets.groupby('YY-MM-DD')['neg'].mean()

avsentimentneg.to_pickle('av_negative_1stcleanbit_DOGE_LAST.pkl')

avsentimentneg
# Out:
# YY-MM-DD
# 2022-03-28    0.026937
# 2022-03-29    0.021883
# 2022-03-30    0.028584
# 2022-03-31    0.032092
# 2022-04-01    0.035360
# 2022-04-02    0.029473
# 2022-04-03    0.040429
# 2022-04-04    0.022370
# 2022-04-05    0.023957
# 2022-04-06    0.026193
# 2022-04-07    0.040614
# 2022-04-08    0.025418
# 2022-04-09    0.030902
# 2022-04-10    0.029268
# 2022-04-11    0.034858
# 2022-04-12    0.034303
# 2022-04-13    0.035963
# 2022-04-14    0.034081
# 2022-04-15    0.027254
# 2022-04-16    0.025019
# 2022-04-17    0.027524
# 2022-04-18    0.037356
# 2022-04-19    0.030359
# 2022-04-20    0.027563
# 2022-04-21    0.031499
# 2022-04-22    0.035490
# 2022-04-23    0.027009
# 2022-04-24    0.029148
# 2022-04-25    0.026200
# 2022-04-26    0.033933
# 2022-04-27    0.042696
# 2022-04-28    0.035078
# 2022-04-29    0.031367
# 2022-04-30    0.033221
# 2022-05-01    0.039838
# Name: neg, dtype: float64

# %%
# The mean neutral score per day
avsentimentneu = dogtweets.groupby('YY-MM-DD')['neu'].mean()
avsentimentneu.to_pickle('av_neutral_1stcleanbit_DOGE_LAST.pkl')

avsentimentneu
# Out:
# YY-MM-DD
# 2022-03-28    0.869338
# 2022-03-29    0.867649
# 2022-03-30    0.859529
# 2022-03-31    0.865530
# 2022-04-01    0.864549
# 2022-04-02    0.859065
# 2022-04-03    0.855731
# 2022-04-04    0.869815
# 2022-04-05    0.868322
# 2022-04-06    0.872745
# 2022-04-07    0.857219
# 2022-04-08    0.856169
# 2022-04-09    0.850215
# 2022-04-10    0.865862
# 2022-04-11    0.860972
# 2022-04-12    0.864737
# 2022-04-13    0.858823
# 2022-04-14    0.865887
# 2022-04-15    0.879649
# 2022-04-16    0.876782
# 2022-04-17    0.857480
# 2022-04-18    0.866278
# 2022-04-19    0.866174
# 2022-04-20    0.850653
# 2022-04-21    0.864101
# 2022-04-22    0.864776
# 2022-04-23    0.875234
# 2022-04-24    0.859774
# 2022-04-25    0.857638
# 2022-04-26    0.865486
# 2022-04-27    0.859732
# 2022-04-28    0.853348
# 2022-04-29    0.845994
# 2022-04-30    0.852900
# 2022-05-01    0.846936
# Name: neu, dtype: float64

# %%
type(avsentimentpos)

hm = pd.concat([avsentiment,avsentimentpos,avsentimentneu,avsentimentneg], axis=1)

# %%
hm

hm.to_pickle('DOGE_vader_LAST.pkl')

# %%
# Influencer accounts > 100K. In total, there are  tweets by 'influencer profiles', ie having more than 100K followers

doginfluencers = dogtweets[dogtweets['followers_count'] >= 100000]

doginfluencers
# Out:
#                     user_id  \
# 206     1061349266545885185
# 624     1358176095850229761
# 667                27938182
# 761              1568227771
# 902     1353637182184050689
# ...                     ...
# 134103            354537587
# 134239  1456185079001083914
# 134847  1345898128042569728
# 134959             30699048
# 134978   988992203568562176
#
#                                                   content  retweet_count  \
# 206                      #Dogecoin will make millionaires             92
# 624     This is why Elon buying twitter is such a good...             47
# 667     Peak adolescent mindset: everyone else is a co...           3230
# 761     Which #memecoin will moon the most in the next...            201
# 902          Dogecoin to the moon https://t.co/tXnKAA88wQ             35
# ...                                                   ...            ...
# 134103  This Meme Coin Named After Dogecoin And Elon M...              1
# ...

# %% [markdown]
# CREATING THE INFLUENCER DATA SET

# %%
# The mean compound score per day

avsentimentinfluencers = doginfluencers.groupby('YY-MM-DD')['compound'].mean()

#bittweets['m_compound'] = bittweets.groupby('YY-MM-DD')['compound'].mean()

avsentimentinfluencers

avsentimentinfluencers.to_pickle('av_compound_influencers_DOGE_LAST.pkl')

# %%
# The mean positive score per day
avsentimentposinfluencers = doginfluencers.groupby('YY-MM-DD')['pos'].mean()

avsentimentposinfluencers

avsentimentposinfluencers.to_pickle('av_positive_influencers_DOGE_LAST.pkl')

# %%
# The mean negative score per day
avsentimentneginfluencers = doginfluencers.groupby('YY-MM-DD')['neg'].mean()

avsentimentneginfluencers.to_pickle('av_negative_influencers_DOGE_LAST.pkl')

avsentimentneginfluencers
# Out:
# YY-MM-DD
# 2022-03-28    0.008773
# 2022-03-29    0.006000
# 2022-03-30    0.070385
# 2022-03-31    0.033563
# 2022-04-01    0.030400
# 2022-04-02    0.004133
# 2022-04-03    0.019000
# 2022-04-04    0.010553
# 2022-04-05    0.020286
# 2022-04-06    0.018667
# 2022-04-07    0.040333
# 2022-04-08    0.021900
# 2022-04-09    0.000000
# 2022-04-10    0.057627
# 2022-04-11    0.012667
# 2022-04-12    0.061050
# 2022-04-13    0.053750
# 2022-04-14    0.043559
# 2022-04-15    0.021118
# 2022-04-16    0.000000
# 2022-04-17    0.060850
# 2022-04-18    0.040000
# 2022-04-19    0.029909
# 2022-04-20    0.015385
# 2022-04-21    0.000000
# 2022-04-22    0.013571
# 2022-04-23    0.018231
# 2022-04-24    0.032818
# 2022-04-25    0.021505
# 2022-04-26    0.027479
# 2022-04-27    0.028970
# 2022-04-28    0.022826
# 2022-04-29    0.021548
# 2022-04-30    0.089000
# 2022-05-01    0.016357
# Name: neg, dtype: float64

# %%
# The mean neutral score per day
avsentimentneuinfluencers = doginfluencers.groupby('YY-MM-DD')['neu'].mean()
avsentimentneuinfluencers.to_pickle('av_neutral_influencers_DOGE_LAST.pkl')

avsentimentneuinfluencers
# Out:
# YY-MM-DD
# 2022-03-28    0.921273
# 2022-03-29    0.916375
# 2022-03-30    0.853769
# 2022-03-31    0.895312
# 2022-04-01    0.864000
# 2022-04-02    0.869467
# 2022-04-03    0.867273
# 2022-04-04    0.911947
# 2022-04-05    0.895171
# 2022-04-06    0.853125
# 2022-04-07    0.866111
# 2022-04-08    0.858100
# 2022-04-09    0.854500
# 2022-04-10    0.855339
# 2022-04-11    0.869556
# 2022-04-12    0.858100
# 2022-04-13    0.860000
# 2022-04-14    0.830000
# 2022-04-15    0.847882
# 2022-04-16    0.866231
# 2022-04-17    0.855750
# 2022-04-18    0.806474
# 2022-04-19    0.894364
# 2022-04-20    0.845538
# 2022-04-21    0.866500
# 2022-04-22    0.874357
# 2022-04-23    0.885692
# 2022-04-24    0.904818
# 2022-04-25    0.872485
# 2022-04-26    0.875802
# 2022-04-27    0.882636
# 2022-04-28    0.851609
# 2022-04-29    0.877226
# 2022-04-30    0.837000
# 2022-05-01    0.813714
# Name: neu, dtype: float64

# %%
hmm = pd.concat([avsentimentinfluencers, avsentimentposinfluencers, avsentimentneuinfluencers, avsentimentneginfluencers], axis=1)


hmm.to_pickle('DOGE_vader_influencers_LAST.pkl')

# %%
hmm
# Out:
#             compound       pos       neu       neg
# YY-MM-DD
# 2022-03-28  0.190705  0.069955  0.921273  0.008773
# 2022-03-29  0.285725  0.077625  0.916375  0.006000
# 2022-03-30  0.010154  0.075846  0.853769  0.070385
# 2022-03-31  0.134937  0.071188  0.895312  0.033563
# 2022-04-01  0.202190  0.105600  0.864000  0.030400
# 2022-04-02  0.299893  0.126333  0.869467  0.004133
# 2022-04-03  0.319291  0.113727  0.867273  0.019000
# 2022-04-04  0.186750  0.077500  0.911947  0.010553
# 2022-04-05  0.147589  0.084514  0.895171  0.020286
# 2022-04-06  0.325887  0.128250  0.853125  0.018667
# 2022-04-07  0.268533  0.093611  0.866111  0.040333
# 2022-04-08  0.272570  0.120000  0.858100  0.021900
# 2022-04-09  0.604400  0.145500  0.854500  0.000000
# 2022-04-10  0.116753  0.087051  0.855339  0.057627
# 2022-04-11  0.269664  0.117778  0.869556  0.012667
# 2022-04-12  0.145495  0.080950  0.858100  0.061050
# 2022-04-13  0.167137  0.086250  0.860000  0.053750
# ...

# %% [markdown]
# CREATING THE REGULAR TWEETS DATASET

# %%
dogregular = dogtweets[dogtweets['followers_count'] < 100000]

dogregular
# Out:
#                     user_id  \
# 0                 496949253
# 1       1397225069710020616
# 2       1383085195994095617
# 3       1360217346791604227
# 4        960864046282133504
# ...                     ...
# 135045  1387922429583007755
# 135048  1361760524162113538
# 135049  1178811384387293187
# 135050  1222346095398998022
# 135051  1345670404350771201
#
#                                                   content  retweet_count  \
# 0       Probably was around 2005/6 (ish) might have it...              0
# 1       UN LONG A SANDBOX !! 💥#sandbox #crypto #bitcoi...              0
# 2                Current #Dogecoin Price: $0.1326 📈 🐕+🚀=🌑              0
# 3       I'm just going to leave this here\n#dogecoin #...              0
# 4       1: Bitcoin price is $38480.58 (0.56% 1h)\n2: E...              0
# ...                                                   ...            ...
# 135045  Dogecoin Leaps! But Here's Why An Even Bigger ...              0
# ...

# %%
 #The mean compound score per day

avsentimentregular = dogregular.groupby('YY-MM-DD')['compound'].mean()

#bittweets['m_compound'] = bittweets.groupby('YY-MM-DD')['compound'].mean()

avsentimentregular.to_pickle('av_compound_regular_DOGE_LAST.pkl')

# %%
avsentimentregular
# Out:
# YY-MM-DD
# 2022-03-28    0.200285
# 2022-03-29    0.231324
# 2022-03-30    0.218056
# 2022-03-31    0.186074
# 2022-04-01    0.168153
# 2022-04-02    0.218640
# 2022-04-03    0.149298
# 2022-04-04    0.216653
# 2022-04-05    0.197637
# 2022-04-06    0.182785
# 2022-04-07    0.155534
# 2022-04-08    0.223734
# 2022-04-09    0.215900
# 2022-04-10    0.192626
# 2022-04-11    0.175113
# 2022-04-12    0.185820
# 2022-04-13    0.191644
# 2022-04-14    0.175790
# 2022-04-15    0.178038
# 2022-04-16    0.175327
# 2022-04-17    0.208927
# 2022-04-18    0.148097
# 2022-04-19    0.182853
# 2022-04-20    0.216135
# 2022-04-21    0.194520
# 2022-04-22    0.174018
# 2022-04-23    0.179046
# 2022-04-24    0.210048
# 2022-04-25    0.215964
# 2022-04-26    0.179188
# 2022-04-27    0.152736
# 2022-04-28    0.197574
# 2022-04-29    0.227710
# 2022-04-30    0.214300
# 2022-05-01    0.194713
# Name: compound, dtype: float64

# %%
avsentimentregular
# Out:
# YY-MM-DD
# 2022-03-28    0.200285
# 2022-03-29    0.231324
# 2022-03-30    0.218056
# 2022-03-31    0.186074
# 2022-04-01    0.168153
# 2022-04-02    0.218640
# 2022-04-03    0.149298
# 2022-04-04    0.216653
# 2022-04-05    0.197637
# 2022-04-06    0.182785
# 2022-04-07    0.155534
# 2022-04-08    0.223734
# 2022-04-09    0.215900
# 2022-04-10    0.192626
# 2022-04-11    0.175113
# 2022-04-12    0.185820
# 2022-04-13    0.191644
# 2022-04-14    0.175790
# 2022-04-15    0.178038
# 2022-04-16    0.175327
# 2022-04-17    0.208927
# 2022-04-18    0.148097
# 2022-04-19    0.182853
# 2022-04-20    0.216135
# 2022-04-21    0.194520
# 2022-04-22    0.174018
# 2022-04-23    0.179046
# 2022-04-24    0.210048
# 2022-04-25    0.215964
# 2022-04-26    0.179188
# 2022-04-27    0.152736
# 2022-04-28    0.197574
# 2022-04-29    0.227710
# 2022-04-30    0.214300
# 2022-05-01    0.194713
# Name: compound, dtype: float64

# %%
# The mean positive score per day
avsentimentposregular = dogregular.groupby('YY-MM-DD')['pos'].mean()

avsentimentposregular.to_pickle('av_positive_regular_DOGE_LAST.pkl')

# %%
# The mean negative score per day
avsentimentnegregular = dogregular.groupby('YY-MM-DD')['neg'].mean()

avsentimentnegregular.to_pickle('av_negative_regular_DOGE_LAST.pkl')

avsentimentnegregular
# Out:
# YY-MM-DD
# 2022-03-28    0.027095
# 2022-03-29    0.021952
# 2022-03-30    0.028319
# 2022-03-31    0.032082
# 2022-04-01    0.035382
# 2022-04-02    0.029682
# 2022-04-03    0.040677
# 2022-04-04    0.022491
# 2022-04-05    0.023979
# 2022-04-06    0.026250
# 2022-04-07    0.040616
# 2022-04-08    0.025443
# 2022-04-09    0.030972
# 2022-04-10    0.028796
# 2022-04-11    0.035141
# 2022-04-12    0.034085
# 2022-04-13    0.035835
# 2022-04-14    0.033980
# 2022-04-15    0.027342
# 2022-04-16    0.025129
# 2022-04-17    0.027246
# 2022-04-18    0.037337
# 2022-04-19    0.030361
# 2022-04-20    0.027670
# 2022-04-21    0.031643
# 2022-04-22    0.035638
# 2022-04-23    0.027061
# 2022-04-24    0.029127
# 2022-04-25    0.026256
# 2022-04-26    0.034012
# 2022-04-27    0.042814
# 2022-04-28    0.035171
# 2022-04-29    0.031447
# 2022-04-30    0.032917
# 2022-05-01    0.039966
# Name: neg, dtype: float64

# %%
# The mean neutral score per day
avsentimentneuregular = dogregular.groupby('YY-MM-DD')['neu'].mean()
avsentimentneuregular.to_pickle('av_neutral_regular_DOGE_LST.pkl')

# %%
hmmm = pd.concat([avsentimentregular, avsentimentposregular, avsentimentneuregular, avsentimentnegregular], axis=1)


hmmm.to_pickle('DOGE_vader_regular_LAST.pkl')

# %%
hmm
# Out:
#             compound       pos       neu       neg
# YY-MM-DD
# 2022-03-28  0.190705  0.069955  0.921273  0.008773
# 2022-03-29  0.285725  0.077625  0.916375  0.006000
# 2022-03-30  0.010154  0.075846  0.853769  0.070385
# 2022-03-31  0.134937  0.071188  0.895312  0.033563
# 2022-04-01  0.202190  0.105600  0.864000  0.030400
# 2022-04-02  0.299893  0.126333  0.869467  0.004133
# 2022-04-03  0.319291  0.113727  0.867273  0.019000
# 2022-04-04  0.186750  0.077500  0.911947  0.010553
# 2022-04-05  0.147589  0.084514  0.895171  0.020286
# 2022-04-06  0.325887  0.128250  0.853125  0.018667
# 2022-04-07  0.268533  0.093611  0.866111  0.040333
# 2022-04-08  0.272570  0.120000  0.858100  0.021900
# 2022-04-09  0.604400  0.145500  0.854500  0.000000
# 2022-04-10  0.116753  0.087051  0.855339  0.057627
# 2022-04-11  0.269664  0.117778  0.869556  0.012667
# 2022-04-12  0.145495  0.080950  0.858100  0.061050
# 2022-04-13  0.167137  0.086250  0.860000  0.053750
# ...

# %%
# Plotting the number of tweets per day by 'influencer' profiles

plt.rcParams['figure.figsize'] = 28,10

plt.hist(doginfluencers['YY-MM-DD'], bins=35,color = 'paleturquoise', rwidth=0.7)
plt.ylabel('Number of tweets')
plt.xlabel('Date')
plt.title("Number of tweets per day by influencers ", fontdict=None, position= [0.50,1.05], size = 'x-large')
plt.show()

#Each day has at least some tweets by profiles with >100K followers, so it can be used in separate models to test weather tweets by influencers have more predictive power in comparison to other accounts.Still some days have less than 100 tweets, so they could be not representative. Depending on the model, assigning weight to the followers count could also be an option.

# %%
# Plotting the number of tweets per day by NOT 'influencer' profiles

plt.rcParams['figure.figsize'] = 28,10

plt.hist(dogregular['YY-MM-DD'], bins=35,color = 'paleturquoise', rwidth=0.7)
plt.ylabel('Number of tweets')
plt.xlabel('Date')
plt.title("Number of tweets per day by NOT influencers ", fontdict=None, position= [0.50,1.05], size = 'x-large')
plt.show()

# %% [markdown]
# Merging all datasets

# %%
vader = pd.read_pickle('DOGE_vader_LAST.pkl')
vaderregular = pd.read_pickle('DOGE_vader_regular_LAST.pkl')
vaderinfluencers = pd.read_pickle('DOGE_vader_influencers_LAST.pkl')

# %%
doge = pd.read_csv('dogeday.csv')

# %%
doge
# Out:
#            unix       date    symbol     open     high      low    close  \
# 0    1652400000  5/13/2022  DOGE/USD  0.08309  0.09500  0.08222  0.08757
# 1    1652313600  5/12/2022  DOGE/USD  0.08501  0.08881  0.06772  0.08261
# 2    1652227200  5/11/2022  DOGE/USD  0.10824  0.11052  0.07198  0.08449
# 3    1652140800  5/10/2022  DOGE/USD  0.10189  0.11811  0.10000  0.10819
# 4    1652054400   5/9/2022  DOGE/USD  0.12415  0.12512  0.10119  0.10186
# ..          ...        ...       ...      ...      ...      ...      ...
# 314  1625270400   7/3/2021  DOGE/USD  0.25125  0.25600  0.24100  0.25277
# 315  1625184000   7/2/2021  DOGE/USD  0.25910  0.26890  0.24151  0.24415
# 316  1625097600   7/1/2021  DOGE/USD  0.25800  0.27700  0.24100  0.26010
# 317  1625011200  6/30/2021  DOGE/USD  4.80000  4.80000  0.24500  0.30500
# 318  1624579200  6/25/2021  DOGE/USD  0.24075  0.24075  0.24075  0.24075
#
#       Volume DOGE    Volume USD
# 0    4.321293e+05   37841.56367
# ...

# %%
doge['date'] = pd.to_datetime(doge['date'])
doge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix         319 non-null    int64
#  1   date         319 non-null    datetime64[ns]
#  2   symbol       319 non-null    object
#  3   open         319 non-null    float64
#  4   high         319 non-null    float64
#  5   low          319 non-null    float64
#  6   close        319 non-null    float64
#  7   Volume DOGE  319 non-null    float64
#  8   Volume USD   319 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(1)
# memory usage: 22.6+ KB

# %%
dfdoge = doge.loc[(doge['date'] > '2022-03-24') & (doge['date'] <= '2022-05-01')]

# %%
doge = dfdoge.set_index('date')

# %%
vader
# Out:
#             compound       pos       neu       neg
# YY-MM-DD
# 2022-03-28  0.200202  0.103727  0.869338  0.026937
# 2022-03-29  0.231560  0.110467  0.867649  0.021883
# 2022-03-30  0.216748  0.111886  0.859529  0.028584
# 2022-03-31  0.185723  0.102380  0.865530  0.032092
# 2022-04-01  0.168305  0.100100  0.864549  0.035360
# 2022-04-02  0.219305  0.111463  0.859065  0.029473
# 2022-04-03  0.151238  0.103841  0.855731  0.040429
# 2022-04-04  0.216350  0.107819  0.869815  0.022370
# 2022-04-05  0.197334  0.107718  0.868322  0.023957
# 2022-04-06  0.183847  0.101059  0.872745  0.026193
# 2022-04-07  0.156316  0.102171  0.857219  0.040614
# 2022-04-08  0.224081  0.118413  0.856169  0.025418
# 2022-04-09  0.216776  0.118882  0.850215  0.030902
# 2022-04-10  0.191385  0.104870  0.865862  0.029268
# 2022-04-11  0.176301  0.104161  0.860972  0.034858
# 2022-04-12  0.185495  0.100959  0.864737  0.034303
# 2022-04-13  0.191469  0.105212  0.858823  0.035963
# ...

# %%
vaderregular
#little to no difference, as most posts fall in the regular cat
# Out:
#             compound       pos       neu       neg
# YY-MM-DD
# 2022-03-28  0.200285  0.104021  0.868885  0.027095
# 2022-03-29  0.231324  0.110610  0.867437  0.021952
# 2022-03-30  0.218056  0.112114  0.859565  0.028319
# 2022-03-31  0.186074  0.102596  0.865324  0.032082
# 2022-04-01  0.168153  0.100075  0.864552  0.035382
# 2022-04-02  0.218640  0.111340  0.858980  0.029682
# 2022-04-03  0.149298  0.103727  0.855598  0.040677
# 2022-04-04  0.216653  0.108129  0.869384  0.022491
# 2022-04-05  0.197637  0.107860  0.868158  0.023979
# 2022-04-06  0.182785  0.100855  0.872892  0.026250
# 2022-04-07  0.155534  0.102230  0.857157  0.040616
# 2022-04-08  0.223734  0.118402  0.856155  0.025443
# 2022-04-09  0.215900  0.118822  0.850205  0.030972
# 2022-04-10  0.192626  0.105166  0.866037  0.028796
# 2022-04-11  0.175113  0.103987  0.860863  0.035141
# 2022-04-12  0.185820  0.101122  0.864791  0.034085
# 2022-04-13  0.191644  0.105349  0.858814  0.035835
# ...

# %%
vaderinfluencers = vaderinfluencers.add_prefix("inf_")

# %%
dfdo=pd.merge(doge,vader, how='inner', left_index=True, right_index=True)

# %%
dfdo
# Out:
#                   unix    symbol     open     high      low    close  \
# 2022-05-01  1651363200  DOGE/USD  0.12737  0.13636  0.12698  0.13266
# 2022-04-30  1651276800  DOGE/USD  0.13501  0.13675  0.12500  0.12731
# 2022-04-29  1651190400  DOGE/USD  0.13731  0.14449  0.13000  0.13487
# 2022-04-28  1651104000  DOGE/USD  0.13968  0.14356  0.13600  0.13729
# 2022-04-27  1651017600  DOGE/USD  0.13771  0.14556  0.13601  0.13946
# 2022-04-26  1650931200  DOGE/USD  0.15833  0.16640  0.13573  0.13783
# 2022-04-25  1650844800  DOGE/USD  0.13182  0.17073  0.12274  0.15854
# 2022-04-24  1650758400  DOGE/USD  0.13392  0.13501  0.13148  0.13180
# 2022-04-23  1650672000  DOGE/USD  0.13648  0.13648  0.13370  0.13370
# 2022-04-22  1650585600  DOGE/USD  0.13623  0.13800  0.13450  0.13648
# 2022-04-21  1650499200  DOGE/USD  0.14095  0.14260  0.13446  0.13606
# 2022-04-20  1650412800  DOGE/USD  0.14236  0.14625  0.13941  0.14088
# 2022-04-19  1650326400  DOGE/USD  0.14013  0.14407  0.13867  0.14249
# ...

# %%
df=pd.merge(dfdo,vaderinfluencers, how='inner', left_index=True, right_index=True)

# %%
df
# Out:
#                   unix    symbol     open     high      low    close  \
# 2022-05-01  1651363200  DOGE/USD  0.12737  0.13636  0.12698  0.13266
# 2022-04-30  1651276800  DOGE/USD  0.13501  0.13675  0.12500  0.12731
# 2022-04-29  1651190400  DOGE/USD  0.13731  0.14449  0.13000  0.13487
# 2022-04-28  1651104000  DOGE/USD  0.13968  0.14356  0.13600  0.13729
# 2022-04-27  1651017600  DOGE/USD  0.13771  0.14556  0.13601  0.13946
# 2022-04-26  1650931200  DOGE/USD  0.15833  0.16640  0.13573  0.13783
# 2022-04-25  1650844800  DOGE/USD  0.13182  0.17073  0.12274  0.15854
# 2022-04-24  1650758400  DOGE/USD  0.13392  0.13501  0.13148  0.13180
# 2022-04-23  1650672000  DOGE/USD  0.13648  0.13648  0.13370  0.13370
# 2022-04-22  1650585600  DOGE/USD  0.13623  0.13800  0.13450  0.13648
# 2022-04-21  1650499200  DOGE/USD  0.14095  0.14260  0.13446  0.13606
# 2022-04-20  1650412800  DOGE/USD  0.14236  0.14625  0.13941  0.14088
# 2022-04-19  1650326400  DOGE/USD  0.14013  0.14407  0.13867  0.14249
# ...

# %%
df.to_pickle('DOGEALL_price_vader_LAST.pkl')

# %%
p = plt.plot(df.index, df.close)
plt.ylabel('Close Price', fontsize = 18)
plt.xlabel('Date', fontsize = 18)
plt.title("Dogecoin Daily Close Price", fontdict=None, position= [0.50,1.05], fontsize = 20)
plt.savefig('dogeclose.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

plt.show()
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/2648357769.py:5: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogeclose.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/2648357769.py:5: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogeclose.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

# %%
df.describe()
# Out:
#                unix       open       high        low      close   Volume DOGE  \
# count  3.500000e+01  35.000000  35.000000  35.000000  35.000000  3.500000e+01
# mean   1.649894e+09   0.141982   0.148895   0.136675   0.141641  4.147684e+05
# std    8.853365e+05   0.007577   0.010980   0.005611   0.007769  5.076530e+05
# min    1.648426e+09   0.127370   0.135010   0.122740   0.127310  8.202450e+04
# 25%    1.649160e+09   0.137945   0.143235   0.133930   0.137560  1.997055e+05
# 50%    1.649894e+09   0.141190   0.146200   0.136870   0.140880  2.449517e+05
# 75%    1.650629e+09   0.144380   0.150870   0.141515   0.144320  4.155148e+05
# max    1.651363e+09   0.171610   0.186000   0.147860   0.171650  2.584708e+06
#
#           Volume USD   compound        pos        neu        neg  \
# count      35.000000  35.000000  35.000000  35.000000  35.000000
# mean    61021.559871   0.192677   0.106620   0.862145   0.031235
# std     80890.088541   0.022619   0.007629   0.008050   0.005345
# ...

# %%
df.describe().to_csv("my_description_Doge.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13824/802919931.py in <module>
# ----> 1 df.describe().to_csv("my_description_Doge.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ...

# %%
df = df.drop(['unix', 'Volume USD'], axis=1)

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, cmap='coolwarm_r').set(title = "co")
plt.title("Correlation plot Dogecoin", fontdict=None, position= [0.50,1.05], fontsize = 20)
plt.savefig('dogcorr.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

plt.show()
# Out:
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/986929182.py:4: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogcorr.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)
# C:\Users\dayan\AppData\Local\Temp/ipykernel_13824/986929182.py:4: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "frameon" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('dogcorr.png', dpi=None, facecolor='w', edgecolor='w', orientation='portrait', papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

# %%
df
# Out:
#               symbol     open     high      low    close   Volume DOGE  \
# 2022-05-01  DOGE/USD  0.12737  0.13636  0.12698  0.13266  2.065414e+05
# 2022-04-30  DOGE/USD  0.13501  0.13675  0.12500  0.12731  2.662943e+05
# 2022-04-29  DOGE/USD  0.13731  0.14449  0.13000  0.13487  4.037294e+05
# 2022-04-28  DOGE/USD  0.13968  0.14356  0.13600  0.13729  2.449517e+05
# 2022-04-27  DOGE/USD  0.13771  0.14556  0.13601  0.13946  4.427208e+05
# 2022-04-26  DOGE/USD  0.15833  0.16640  0.13573  0.13783  1.230334e+06
# 2022-04-25  DOGE/USD  0.13182  0.17073  0.12274  0.15854  2.584708e+06
# 2022-04-24  DOGE/USD  0.13392  0.13501  0.13148  0.13180  8.202450e+04
# 2022-04-23  DOGE/USD  0.13648  0.13648  0.13370  0.13370  1.464467e+05
# 2022-04-22  DOGE/USD  0.13623  0.13800  0.13450  0.13648  2.568925e+05
# 2022-04-21  DOGE/USD  0.14095  0.14260  0.13446  0.13606  1.994548e+05
# 2022-04-20  DOGE/USD  0.14236  0.14625  0.13941  0.14088  2.045860e+05
# ...
